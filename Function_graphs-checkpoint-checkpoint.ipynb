# %% [markdown]
# # Nina's code for bar chart

# %%
import csv
import pandas as pd
import numpy
import scipy.stats as st
from scipy.stats import linregress
import time
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import re

# %%
data = pd.read_csv('Output/ultimate_no_null.csv')

# %%
data.head()
# Out:
#   standard_names  month  year  Confirmed  stringency_index       lat  \
# 0    Afghanistan      1  2020        0.0          0.000000  33.93911
# 1    Afghanistan      2  2020        1.0          2.010690  33.93911
# 2    Afghanistan      3  2020      174.0         40.831935  33.93911
# 3    Afghanistan      4  2020     1952.0         80.740000  33.93911
# 4    Afghanistan      5  2020    13081.0         84.260000  33.93911
#
#          lng  Population (2020)  Density (P/Km²) Infection_rate ISO_2 ISO_3  \
# 0  67.709953           39074280               60        0.0000%    AF   AFG
# 1  67.709953           39074280               60        0.0000%    AF   AFG
# 2  67.709953           39074280               60        0.0004%    AF   AFG
# 3  67.709953           39074280               60        0.0050%    AF   AFG
# 4  67.709953           39074280               60        0.0335%    AF   AFG
#
#    Infection_rate_f
# 0            0.0000
# 1            0.0000
# 2            0.0004
# ...

# %%
data['Infection_rate'] = data['Infection_rate'].str.rstrip("%").astype("float")
data.head()
# Out:
#   standard_names  month  year  Confirmed  stringency_index       lat  \
# 0    Afghanistan      1  2020        0.0          0.000000  33.93911
# 1    Afghanistan      2  2020        1.0          2.010690  33.93911
# 2    Afghanistan      3  2020      174.0         40.831935  33.93911
# 3    Afghanistan      4  2020     1952.0         80.740000  33.93911
# 4    Afghanistan      5  2020    13081.0         84.260000  33.93911
#
#          lng  Population (2020)  Density (P/Km²)  Infection_rate ISO_2 ISO_3  \
# 0  67.709953           39074280               60          0.0000    AF   AFG
# 1  67.709953           39074280               60          0.0000    AF   AFG
# 2  67.709953           39074280               60          0.0004    AF   AFG
# 3  67.709953           39074280               60          0.0050    AF   AFG
# 4  67.709953           39074280               60          0.0335    AF   AFG
#
#    Infection_rate_f
# 0            0.0000
# 1            0.0000
# 2            0.0004
# ...

# %%
countries = []
for country in data["standard_names"]:
    if country not in countries:
        countries.append(country)
    else:
        continue

print(countries)
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Argentina', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cabo Verde', 'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Congo Republic', 'DR Congo', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Cote d'Ivoire", 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'South Korea', 'Kuwait', 'Kyrgyz Republic', 'La
# ...

# %%
new_df = data[["standard_names","month","stringency_index","Infection_rate"]]

# %%
def country_plots(countries):
    
    country_data = new_df.loc[new_df["standard_names"]==countries]
    fig, ax1 = plt.subplots(figsize=(15,10))
    color = 'tab:green'
    ax1.set_xlabel('month', fontsize=16)
    ax1.set_ylabel('Infection Rate', fontsize=16)
    ax1 = sns.barplot(x='month', y='Infection_rate', data = country_data, palette='summer')
    ax2 = ax1.twinx()
    color = 'tab:red'
    ax2 = sns.lineplot(x='month', y='stringency_index', data = country_data).set_title(f"{countries} Infection Rate vs. Stringency") 
    plt.ylim(0,100)
#     counter = 1
    fig.savefig(f"Images_bar/fig{country}.png")
    plt.ylim(0,100)

# %%
for countries in new_df['standard_names']:
    country_plots(countries)
# Out:
# <ipython-input-8-170d58969ef4>:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax1 = plt.subplots(figsize=(15,10))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2c4936a21128> in <module>
#       1 for countries in new_df['standard_names']:
# ----> 2     country_plots(countries)
#
# <ipython-input-8-170d58969ef4> in country_plots(countries)
#       7     ax1.set_ylabel('Infection Rate', fontsize=16)
#       8     ax1 = sns.barplot(x='month', y='Infection_rate', data = country_data, palette='summer')
# ----> 9     ax2 = ax1.twinx()
#      10     color = 'tab:red'
# ...
